# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = np.linspace(1,10,100)

# %% [markdown]
# # Two options for subplots

# %% [markdown]
# ## Subplot option 1

# %%
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows=2, 
                                            ncols=2, 
                                            figsize=(10,5))

# Plot to each different axis
# ↖
ax1.plot(x, x/2) 

# ↗
ax2.scatter(np.random.random(10),  np.random.random(10)) 

# ↙
ax3.bar(['One', 'Two', 'Three'], np.random.randint(0, 11, 3))

# ↘
ax4.hist(np.random.randn(100))
# Out:
# (array([ 2.,  4.,  8., 18., 17., 27., 10., 11.,  1.,  2.]),
#  array([-3.04481631, -2.43023886, -1.81566141, -1.20108395, -0.5865065 ,
#          0.02807095,  0.64264841,  1.25722586,  1.87180331,  2.48638076,
#          3.10095822]),
#  <BarContainer object of 10 artists>)

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2, 
                       figsize=(10,5))

# Plot to each different index
ax[0, 0].plot(x,x/2)

ax[0, 1].scatter(np.random.random(10),  np.random.random(10)) 

ax[1, 0].bar(['One', 'Two', 'Three'], np.random.randint(0, 11, 3))

ax[1, 1].hist(np.random.randn(100))
# Out:
# (array([ 2.,  1.,  8.,  8.,  8., 24., 19., 17.,  7.,  6.]),
#  array([-2.97218286, -2.48630372, -2.00042458, -1.51454544, -1.02866631,
#         -0.54278717, -0.05690803,  0.42897111,  0.91485025,  1.40072938,
#          1.88660852]),
#  <BarContainer object of 10 artists>)
